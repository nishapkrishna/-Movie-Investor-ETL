# %%
# Importing dependencies
import pandas as pd
from sqlalchemy import create_engine
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Store CSV into dataframe
csv_file = "movie_metadata.csv"
movie_metadata_df = pd.read_csv("movies_metadata.csv",low_memory=False)
movie_metadata_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  FALSE                                                NaN  65000000
# 2  FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  FALSE                                                NaN  16000000
# 4  FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# rename "id" column to "movie_id"
movie_metadata_df = movie_metadata_df.rename(columns={'id':'movie_id'})

# %%
# Copy only the columns we want for the database
bench_movie_metadata_df = movie_metadata_df[['movie_id', 'homepage', 'imdb_id', 'original_title', 'overview','popularity', 'poster_path', 'release_date', 'runtime', 'tagline','title']].copy()

bench_movie_metadata_df.head(3)
# Out:
#   movie_id                              homepage    imdb_id    original_title  \
# 0      862  http://toystory.disney.com/toy-story  tt0114709         Toy Story
# 1     8844                                   NaN  tt0113497           Jumanji
# 2    15602                                   NaN  tt0113228  Grumpier Old Men
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
#
#                         poster_path release_date  runtime  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg   10/30/1995     81.0
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg   12/15/1995    104.0
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg   12/22/1995    101.0
#
#                                              tagline             title
# 0                                                NaN         Toy Story
# ...

# %%
# import datetime for release_year column so we can send to sql workbench
from datetime import datetime
now = datetime.now()
id = 1
formatted_date = now.strftime('%m-%d-%Y %H:%M:%S')

# %% [raw]
# # Ignore for now. Orinal loop. See cell below.
# release_date = []
#
# # loop thru each row
# for idx, rows in movie_metadata_df.iterrows():
# #     formatted_date = rows['release_date'].stpftime('%Y-%m-%d %H:%M:%S')
#
#     try:
#
#         formatted_date = datetime.strptime(rows['release_date'],'%m/%d/%Y' )
#         release_date.append(formatted_date)
#     except:
#
#         try:
#             formatted_date = datetime.strptime(rows['release_date'],'%Y-%m-%d')
#             release_date.append(formatted_date)
#         except:
#
#             pass
#
#
#
#
# release_date

# %%
# loop thru each row to convert entire column of release_date to datetime (strp to breakdown format, then strf to convert
# to string for import to sql database as varchar)
for idx, rows in bench_movie_metadata_df.iterrows():
#     formatted_date = rows['release_date'].stpftime('%Y-%m-%d %H:%M:%S')

    try: 
    
        bench_movie_metadata_df.iloc[idx,7] = (datetime.strptime(rows['release_date'],
                                                                              '%m/%d/%Y' )
                                                                    .strftime('%m-%d-%Y %H:%M:%S')[:10]
                                                           )
    except:
        
        try:
            bench_movie_metadata_df.iloc[idx,7] = (datetime.strptime(rows['release_date'],
                                                                                  '%Y-%m-%d')
                                                                        .strftime('%m-%d-%Y %H:%M:%S')[:10]
                                                               )
        except:
            bench_movie_metadata_df.drop(idx, axis=0)

# %%
# # loop thru each row
# for idx, rows in bench_movie_metadata_df.iterrows():
# #     formatted_date = rows['release_date'].stpftime('%Y-%m-%d %H:%M:%S')

#     try: 
    
#         bench_movie_metadata_df.iloc[idx,'release_date'] = datetime.strptime(rows['release_date'],'%m/%d/%Y' )
#     except:
        
#         try:
#             bench_movie_metadata_df.iloc[idx,'release_date'] = datetime.strptime(rows['release_date'],'%Y-%m-%d')
#         except:
#             bench_movie_metadata_df.drop(idx, axis=0)

# %%
# set format for date, test by returning first date in the row.
datetime.strptime(bench_movie_metadata_df.release_date[0],'%m/%d/%Y').strftime('%m-%d-%Y %H:%M:%S')
# Out:
# '10-30-1995 00:00:00'

# %%
#drop null values
bench_movie_metadata_df.release_date.dropna()
# Out:
# 0        10-30-1995 00:00:00
# 1                  12-15-199
# 2                 12-22-1995
# 3                 12/22/1995
# 4                  2/10/1995
# 5                 12/15/1995
# 6                 12/15/1995
# 7                 12/22/1995
# 8                 12/22/1995
# 9                 11/16/1995
# 10                11/17/1995
# 11                12/22/1995
# 12                12/22/1995
# 13                12/22/1995
# 14                12/22/1995
# 15                11/22/1995
# 16                12/13/1995
# 17                 12/9/1995
# 18                11/10/1995
# 19                11/21/1995
# 20                10/20/1995
# 21                10/27/1995
# 22                 10/6/1995
# 23                10/27/1995
# 24                10/27/1995
# 25                12/15/1995
# 26                10/20/1995
# 27                 9/27/1995
# 28                 5/16/1995
# 29                 4/30/1995
#                 ...
# 45435              3/25/2010
# ...

# %%
bench_movie_metadata_df.head(1)
# Out:
#   movie_id                              homepage    imdb_id original_title  \
# 0      862  http://toystory.disney.com/toy-story  tt0114709      Toy Story
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...    21.9469
#
#                         poster_path         release_date              runtime  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  10-30-1995 00:00:00  10-30-1995 00:00:00
#
#   tagline      title
# 0     NaN  Toy Story

# %%
bench_movie_metadata_df.release_date[2]
# Out:
# '12-22-1995'

# %%
bench_movie_metadata_df.iloc[4,7] = (datetime.strptime(bench_movie_metadata_df.release_date[4],
                                                                              '%m/%d/%Y' )
                                                                    .strftime('%m-%d-%Y %H:%M:%S')[:10]
                                                           )

# %%
# create test dataframe using release date now as datetime obj so it can be sent to sql WB
# release_date_df= pd.DataFrame ({'test_dte': release_date})

# %%
# release_date_df.to_sql(name='test_date', con=engine, if_exists='append', index=False)

# %%
# cursor.execute('insert into table(id, date_created) values(%s, %s)', (id, formatted_date))

# %%
# bench_movie_metadata_df['release_date'] =  pd.date_time(bench_movie_metadata_df['release_date'])
# bench_movie_metadata_df.head()

# %%
# may not work necessary: experimenting.
bench_movie_metadata_df['release_date'] = pd.to_date(bench_movie_metadata_df['release_date'])

# %%
# Connect to local database
rds_connection_string = "root:Kosalamosala1!@127.0.0.1/movies_database"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
# Check for tables
engine.table_names()
# Out:
# ['genres_master',
#  'movie_cast',
#  'movie_crew',
#  'movie_keywords',
#  'movie_links',
#  'movies_finance',
#  'movies_genres',
#  'movies_language',
#  'movies_metadata',
#  'production_companies',
#  'production_countries']

# %%
# Use pandas to load csv converted DataFrame into database
bench_movie_metadata_df.to_sql(name='movies_metadata', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# ...
